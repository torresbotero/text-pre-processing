# %%
import pandas as pd
import itertools

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from experiments_core import run_one_comb_experiment
from experiments_core import norm_repeated_letters
from experiments_core import stem_tokens
from experiments_core import lemmatizer
from experiments_core import save_excel_comb_results
from experiments_core import RepeatReplacer

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer

import xlsxwriter

import re

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import importlib
import sys
importlib.reload(sys.modules[run_one_comb_experiment.__module__])
importlib.reload(sys.modules[norm_repeated_letters.__module__])
importlib.reload(sys.modules[stem_tokens.__module__])
importlib.reload(sys.modules[lemmatizer.__module__])
importlib.reload(sys.modules[save_excel_comb_results.__module__])
# Out:
# <module 'experiments_core' from '/home/ctorres9/EAFIT/trabajogrado/experiments/experiments_core.py'>

# %%
file_path = 'data/TweetsPolaridadSEPLN.csv'
original_tweets_df = pd.read_csv(file_path, index_col=None, header=0, sep='\t')
print(original_tweets_df.describe())
print(original_tweets_df.head())
# Out:
#                       tweetid          user               content  \
# count                   60798         60798                 60798
# unique                  60798           158                 60405
# top      151651854219100160,0  mariviromero  Buenos días a todos!
# freq                        1          7138                   111
#
#                        date   lang polarity  topic
# count                 60798  60798    60798  60798
# unique                60510      1        6     10
# top     2012-01-01T00:00:16     es     NONE  otros
# freq                      4  60798    21416  28189
#                  tweetid            user  \
# 0   142378325086715904,0     jesusmarana
# 1   142379080808013824,0       EvaORegan
# 2   142379173120442368,0  LosadaPescador
# 3   142379815708803072,0    mgilguerrero
# 4   142381190123499520,0  pedroj_ramirez
#
#                                              content                 date  \
# 0  Portada 'Público', viernes. Fabra al banquillo...  2011-12-02T00:03:32
# 1  Grande! RT @veronicacalderon "El periodista es...  2011-12-02T00:06:32
# 2  Gonzalo Altozano tras la presentación de su li...  2011-12-02T00:06:55
# 3  Mañana en Gaceta: TVE, la que pagamos tú y yo,...  2011-12-02T00:09:28
# 4  Qué envidia “@mfcastineiras: Pedro mañana x la...  2011-12-02T00:14:55
#
#   lang polarity            topic
# 0   es        N         política
# 1   es     NONE         política
# 2   es       P+            otros
# 3   es        N  entretenimiento
# 4   es     NONE            otros

# %%
strong_negative_tweets = original_tweets_df[original_tweets_df.polarity == 'N+'][['content','polarity']]
standar_negative_tweets = original_tweets_df[original_tweets_df.polarity == 'N'][['content','polarity']]

strong_positive_tweets = original_tweets_df[original_tweets_df.polarity == 'P+'][['content','polarity']]
standar_positive_tweets = original_tweets_df[original_tweets_df.polarity == 'P'][['content','polarity']]

negative_tweets = pd.concat([strong_negative_tweets,standar_negative_tweets], ignore_index=True)
positive_tweets = pd.concat([strong_positive_tweets,standar_positive_tweets], ignore_index=True)

negative_tweets.polarity = "negative"
positive_tweets.polarity = "positive"

total_tweets = pd.concat([negative_tweets,positive_tweets], ignore_index=True)
print(total_tweets.describe())
print(total_tweets.head())
# Out:
#                                                   content  polarity
# count                                               38077     38077
# unique                                              37926         2
# top     ¡Noticias descombacantes! está disponible! htt...  positive
# freq                                                   63     22233
#                                              content  polarity
# 0  Dado q la deuda privada es superior a la publi...  negative
# 1  TEPCO inyecta nitrógeno en los reactores de Fu...  negative
# 2  “@Declaracion: «Cualquier injusticia contra un...  negative
# 3  ¡Qué estrés!, la presidenta de la diputación d...  negative
# 4  Hoy entrego mi credencial en el Congreso. Una ...  negative

# %%
total_data_content = total_tweets.content
total_data_target = total_tweets.polarity

# %%
X_train, X_test, y_train, y_test = train_test_split(total_data_content, 
                                                    total_data_target, 
                                                    test_size=0.3, 
                                                    random_state=80)

# %%
print("Positivos entrenamiento:", len(y_train[y_train == 'positive']))
print("Negativos entrenamiento:", len(y_train[y_train == 'negative']))
print("Positivos pruebas:", len(y_test[y_test == 'positive']))
print("Negativos pruebas:", len(y_test[y_test == 'negative']))
# Out:
# Positivos entrenamiento: 15552
# Negativos entrenamiento: 11101
# Positivos pruebas: 6681
# Negativos pruebas: 4743

# %%
spanish_stopwords = stopwords.words('spanish')
stemmer = SnowballStemmer('spanish')
replacer = RepeatReplacer()

# %% [markdown]
# # Combinaciones de experimentos para tweets

# %% [markdown]
# Los siguientes son los resultados de las combinaciones entre los diferentes metodos de limpieza y ponderacion en la representacion

# %%
pre_processing_tasks = ['stop_words','stemming','lemmatization','urls','norm_letters','pruning10','pruning5']

# %%
all_the_tasks = []
for r in range(1, len(pre_processing_tasks) + 1):
    all_the_tasks = all_the_tasks + list(itertools.combinations(pre_processing_tasks, r))

# %%
len(all_the_tasks)
# Out:
# 127

# %%
count = 0
tasks_to_remove = []
for comb in all_the_tasks:
    if (('stemming' in comb) and ('lemmatization' in comb)) or (('pruning10' in comb) and ('pruning5' in comb)):
        #all_the_tasks.remove(comb)
        tasks_to_remove.append(comb)
        count += 1
print(count)
print(len(tasks_to_remove))
# Out:
# 56
# 56

# %%
for task in tasks_to_remove:
    all_the_tasks.remove(task)

# %%
all_the_tasks
# Out:
# [('stop_words',),
#  ('stemming',),
#  ('lemmatization',),
#  ('urls',),
#  ('norm_letters',),
#  ('pruning10',),
#  ('pruning5',),
#  ('stop_words', 'stemming'),
#  ('stop_words', 'lemmatization'),
#  ('stop_words', 'urls'),
#  ('stop_words', 'norm_letters'),
#  ('stop_words', 'pruning10'),
#  ('stop_words', 'pruning5'),
#  ('stemming', 'urls'),
#  ('stemming', 'norm_letters'),
#  ('stemming', 'pruning10'),
#  ('stemming', 'pruning5'),
#  ('lemmatization', 'urls'),
#  ('lemmatization', 'norm_letters'),
#  ('lemmatization', 'pruning10'),
#  ('lemmatization', 'pruning5'),
#  ('urls', 'norm_letters'),
#  ('urls', 'pruning10'),
#  ('urls', 'pruning5'),
#  ('norm_letters', 'pruning10'),
#  ('norm_letters', 'pruning5'),
#  ('stop_words', 'stemming', 'urls'),
#  ('stop_words', 'stemming', 'norm_letters'),
#  ('stop_words', 'stemming', 'pruning10'),
#  ('stop_words', 'stemming', 'pruning5'),
#  ('stop_words', 'lemmatization', 'urls'),
#  ('stop_words', 'lemmatization', 'norm_letters'),
#  ('stop_words', 'lemmatization', 'pruning10'),
#  ('stop_words', 'lemmatization', 'pruning5'),
#  ('stop_words', 'urls', 'norm_letters'),
#  ('stop_words', 'urls', 'pruning10'),
#  ('stop_words', 'urls', 'pruning5'),
#  ('stop_words', 'norm_letters', 'pruning10'),
#  ('stop_words', 'norm_letters', 'pruning5'),
#  ('stemming', 'urls', 'norm_letters'),
#  ('stemming', 'urls', 'pruning10'),
#  ('stemming', 'urls', 'pruning5'),
#  ('stemming', 'norm_letters', 'pruning10'),
#  ('stemming', 'norm_letters', 'pruning5'),
#  ('lemmatization', 'urls', 'norm_letters'),
#  ('lemmatization', 'urls', 'pruning10'),
#  ('lemmatization', 'urls', 'pruning5'),
#  ('lemmatization', 'norm_letters', 'pruning10'),
#  ('lemmatization', 'norm_letters', 'pruning5'),
#  ('urls', 'norm_letters', 'pruning10'),
#  ('urls', 'norm_letters', 'pruning5'),
#  ('stop_words', 'stemming', 'urls', 'norm_letters'),
#  ('stop_words', 'stemming', 'urls', 'pruning10'),
#  ('stop_words', 'stemming', 'urls', 'pruning5'),
#  ('stop_words', 'stemming', 'norm_letters', 'pruning10'),
#  ('stop_words', 'stemming', 'norm_letters', 'pruning5'),
#  ('stop_words', 'lemmatization', 'urls', 'norm_letters'),
#  ('stop_words', 'lemmatization', 'urls', 'pruning10'),
#  ('stop_words', 'lemmatization', 'urls', 'pruning5'),
#  ('stop_words', 'lemmatization', 'norm_letters', 'pruning10'),
#  ('stop_words', 'lemmatization', 'norm_letters', 'pruning5'),
#  ('stop_words', 'urls', 'norm_letters', 'pruning10'),
#  ('stop_words', 'urls', 'norm_letters', 'pruning5'),
#  ('stemming', 'urls', 'norm_letters', 'pruning10'),
#  ('stemming', 'urls', 'norm_letters', 'pruning5'),
#  ('lemmatization', 'urls', 'norm_letters', 'pruning10'),
#  ('lemmatization', 'urls', 'norm_letters', 'pruning5'),
#  ('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning10'),
#  ('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning5'),
#  ('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning10'),
#  ('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning5')]

# %%
comb_test = [('stop_words'),('stemming'), ('lemmatization'), ('urls'), ('norm_letters'), ('pruning10'), ('pruning5')]

# %%
clf_types_weighting_types = [{'clf_name': 'SVM_radial', 'clf_type': SVC(), 
                              'weighting_type': 'TF', 'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [100]}, 'random_state': 30},
                             {'clf_name': 'SVM_radial', 'clf_type': SVC(), 
                              'weighting_type': 'TF-IDF', 'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [1000]}, 'random_state': 10},
                             {'clf_name': 'SVM_radial', 'clf_type': SVC(), 
                              'weighting_type': 'Binario', 'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [100]}, 'random_state': 30}]

# %%
clf_types_weighting_types
# Out:
# [{'clf_name': 'SVM_radial',
#   'clf_type': SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False),
#   'weighting_type': 'TF',
#   'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [100]},
#   'random_state': 30},
#  {'clf_name': 'SVM_radial',
#   'clf_type': SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False),
#   'weighting_type': 'TF-IDF',
#   'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [1000]},
#   'random_state': 10},
#  {'clf_name': 'SVM_radial',
#   'clf_type': SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False),
#   'weighting_type': 'Binario',
#   'optimal_parameters': {'kernel': ['rbf'], 'gamma': [0.001], 'C': [100]},
#   'random_state': 30}]

# %%
vectorizers_list = []
results_list = []
workbook = xlsxwriter.Workbook('result_combinations_tweets_svm_rbf.xlsx')
for clf_type_weighting_type in clf_types_weighting_types:
    ws_name = clf_type_weighting_type['clf_name'] + '_' + clf_type_weighting_type['weighting_type']
    worksheet = workbook.add_worksheet(ws_name)
    init_row = 0
    for comb in all_the_tasks:
        
        if clf_type_weighting_type['weighting_type'] == 'TF':
            vectorizer = CountVectorizer()
        if clf_type_weighting_type['weighting_type'] == 'TF-IDF':
            vectorizer = TfidfVectorizer()
        if clf_type_weighting_type['weighting_type'] == 'Binario':
            vectorizer = CountVectorizer(binary=True)
        
        clf_type = clf_type_weighting_type['clf_type']
        optimal_parameters = clf_type_weighting_type['optimal_parameters']
        random_state = clf_type_weighting_type['random_state']
        
        def tokenize_combinations(text):
            if ('urls' in comb):
                url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
                text = re.sub(url_regex, '', text, flags=re.MULTILINE)

            regexp_tokenizer = RegexpTokenizer(u'(?u)\\b\\w\\w+\\b')
            tokens =  regexp_tokenizer.tokenize(text)

            if ('norm_letters' in comb):
                tokens = norm_repeated_letters(tokens, replacer)

            if ('stemming' in comb):
                tokens = stem_tokens(tokens, stemmer)

            if ('lemmatization' in comb):
                tokens = lemmatizer(tokens)

            return tokens

        vectorizer.set_params(tokenizer = tokenize_combinations)
        
        if ('stop_words' in comb):
            vectorizer.set_params(stop_words = spanish_stopwords)
            
        if ('pruning10' in comb):
            vectorizer.set_params(min_df=10)
            
        if ('pruning5' in comb):
            vectorizer.set_params(min_df=5)
            
        print(ws_name + str(comb))
        exp_results = run_one_comb_experiment(total_data_content, total_data_target, vectorizer, optimal_parameters, clf_type, random_state)
        continue_row = save_excel_comb_results(worksheet, init_row, exp_results, str(optimal_parameters), random_state, str(comb))
        init_row = continue_row
        vectorizers_list.append(vectorizer)
        results_list.append(exp_results + (ws_name, str(comb)))
workbook.close()
# Out:
# SVM_radial_TF('stop_words',)
# train time: 256.494s
# SVM_radial_TF('stemming',)
# train time: 275.685s
# SVM_radial_TF('lemmatization',)
# train time: 283.215s
# SVM_radial_TF('urls',)
# train time: 355.468s
# SVM_radial_TF('norm_letters',)
# train time: 402.208s
# SVM_radial_TF('pruning10',)
# train time: 197.587s
# SVM_radial_TF('pruning5',)
# train time: 269.428s
# SVM_radial_TF('stop_words', 'stemming')
# train time: 243.926s
# SVM_radial_TF('stop_words', 'lemmatization')
# train time: 242.433s
# SVM_radial_TF('stop_words', 'urls')
# train time: 247.232s
# SVM_radial_TF('stop_words', 'norm_letters')
# train time: 265.853s
# SVM_radial_TF('stop_words', 'pruning10')
# train time: 118.505s
# SVM_radial_TF('stop_words', 'pruning5')
# train time: 159.644s
# SVM_radial_TF('stemming', 'urls')
# train time: 251.837s
# SVM_radial_TF('stemming', 'norm_letters')
# train time: 294.671s
# SVM_radial_TF('stemming', 'pruning10')
# train time: 177.006s
# SVM_radial_TF('stemming', 'pruning5')
# train time: 205.871s
# SVM_radial_TF('lemmatization', 'urls')
# train time: 255.567s
# SVM_radial_TF('lemmatization', 'norm_letters')
# train time: 289.701s
# SVM_radial_TF('lemmatization', 'pruning10')
# train time: 177.022s
# SVM_radial_TF('lemmatization', 'pruning5')
# train time: 212.096s
# SVM_radial_TF('urls', 'norm_letters')
# train time: 342.111s
# SVM_radial_TF('urls', 'pruning10')
# train time: 187.967s
# SVM_radial_TF('urls', 'pruning5')
# train time: 233.532s
# SVM_radial_TF('norm_letters', 'pruning10')
# train time: 193.470s
# SVM_radial_TF('norm_letters', 'pruning5')
# train time: 238.230s
# SVM_radial_TF('stop_words', 'stemming', 'urls')
# train time: 187.755s
# SVM_radial_TF('stop_words', 'stemming', 'norm_letters')
# train time: 235.577s
# SVM_radial_TF('stop_words', 'stemming', 'pruning10')
# train time: 126.667s
# SVM_radial_TF('stop_words', 'stemming', 'pruning5')
# train time: 157.851s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls')
# train time: 203.552s
# SVM_radial_TF('stop_words', 'lemmatization', 'norm_letters')
# train time: 221.886s
# SVM_radial_TF('stop_words', 'lemmatization', 'pruning10')
# train time: 126.137s
# SVM_radial_TF('stop_words', 'lemmatization', 'pruning5')
# train time: 157.652s
# SVM_radial_TF('stop_words', 'urls', 'norm_letters')
# train time: 252.217s
# SVM_radial_TF('stop_words', 'urls', 'pruning10')
# train time: 115.843s
# SVM_radial_TF('stop_words', 'urls', 'pruning5')
# train time: 157.470s
# SVM_radial_TF('stop_words', 'norm_letters', 'pruning10')
# train time: 120.626s
# SVM_radial_TF('stop_words', 'norm_letters', 'pruning5')
# train time: 164.046s
# SVM_radial_TF('stemming', 'urls', 'norm_letters')
# train time: 267.526s
# SVM_radial_TF('stemming', 'urls', 'pruning10')
# train time: 175.685s
# SVM_radial_TF('stemming', 'urls', 'pruning5')
# train time: 210.034s
# SVM_radial_TF('stemming', 'norm_letters', 'pruning10')
# train time: 177.870s
# SVM_radial_TF('stemming', 'norm_letters', 'pruning5')
# train time: 226.789s
# SVM_radial_TF('lemmatization', 'urls', 'norm_letters')
# train time: 257.337s
# SVM_radial_TF('lemmatization', 'urls', 'pruning10')
# train time: 163.693s
# SVM_radial_TF('lemmatization', 'urls', 'pruning5')
# train time: 207.363s
# SVM_radial_TF('lemmatization', 'norm_letters', 'pruning10')
# train time: 182.029s
# SVM_radial_TF('lemmatization', 'norm_letters', 'pruning5')
# train time: 220.502s
# SVM_radial_TF('urls', 'norm_letters', 'pruning10')
# train time: 196.193s
# SVM_radial_TF('urls', 'norm_letters', 'pruning5')
# train time: 245.127s
# SVM_radial_TF('stop_words', 'stemming', 'urls', 'norm_letters')
# train time: 193.070s
# SVM_radial_TF('stop_words', 'stemming', 'urls', 'pruning10')
# train time: 121.494s
# SVM_radial_TF('stop_words', 'stemming', 'urls', 'pruning5')
# train time: 156.425s
# SVM_radial_TF('stop_words', 'stemming', 'norm_letters', 'pruning10')
# train time: 127.732s
# SVM_radial_TF('stop_words', 'stemming', 'norm_letters', 'pruning5')
# train time: 160.304s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls', 'norm_letters')
# train time: 207.892s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls', 'pruning10')
# train time: 118.478s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls', 'pruning5')
# train time: 160.132s
# SVM_radial_TF('stop_words', 'lemmatization', 'norm_letters', 'pruning10')
# train time: 127.834s
# SVM_radial_TF('stop_words', 'lemmatization', 'norm_letters', 'pruning5')
# train time: 164.121s
# SVM_radial_TF('stop_words', 'urls', 'norm_letters', 'pruning10')
# train time: 121.463s
# SVM_radial_TF('stop_words', 'urls', 'norm_letters', 'pruning5')
# train time: 159.826s
# SVM_radial_TF('stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 179.239s
# SVM_radial_TF('stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 224.050s
# SVM_radial_TF('lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 174.112s
# SVM_radial_TF('lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 205.601s
# SVM_radial_TF('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 128.639s
# SVM_radial_TF('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 152.016s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 120.336s
# SVM_radial_TF('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 160.681s
# SVM_radial_TF-IDF('stop_words',)
# train time: 513.670s
# SVM_radial_TF-IDF('stemming',)
# train time: 307.280s
# SVM_radial_TF-IDF('lemmatization',)
# train time: 386.966s
# SVM_radial_TF-IDF('urls',)
# train time: 424.075s
# SVM_radial_TF-IDF('norm_letters',)
# train time: 484.446s
# SVM_radial_TF-IDF('pruning10',)
# train time: 201.220s
# SVM_radial_TF-IDF('pruning5',)
# train time: 252.553s
# SVM_radial_TF-IDF('stop_words', 'stemming')
# train time: 267.866s
# SVM_radial_TF-IDF('stop_words', 'lemmatization')
# train time: 290.782s
# SVM_radial_TF-IDF('stop_words', 'urls')
# train time: 331.420s
# SVM_radial_TF-IDF('stop_words', 'norm_letters')
# train time: 372.802s
# SVM_radial_TF-IDF('stop_words', 'pruning10')
# train time: 152.715s
# SVM_radial_TF-IDF('stop_words', 'pruning5')
# train time: 189.256s
# SVM_radial_TF-IDF('stemming', 'urls')
# train time: 299.466s
# SVM_radial_TF-IDF('stemming', 'norm_letters')
# train time: 317.054s
# SVM_radial_TF-IDF('stemming', 'pruning10')
# train time: 179.693s
# SVM_radial_TF-IDF('stemming', 'pruning5')
# train time: 220.458s
# SVM_radial_TF-IDF('lemmatization', 'urls')
# train time: 333.140s
# SVM_radial_TF-IDF('lemmatization', 'norm_letters')
# train time: 362.694s
# SVM_radial_TF-IDF('lemmatization', 'pruning10')
# train time: 174.916s
# SVM_radial_TF-IDF('lemmatization', 'pruning5')
# train time: 242.593s
# SVM_radial_TF-IDF('urls', 'norm_letters')
# train time: 423.681s
# SVM_radial_TF-IDF('urls', 'pruning10')
# train time: 193.885s
# SVM_radial_TF-IDF('urls', 'pruning5')
# train time: 246.606s
# SVM_radial_TF-IDF('norm_letters', 'pruning10')
# train time: 186.690s
# SVM_radial_TF-IDF('norm_letters', 'pruning5')
# train time: 255.076s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls')
# train time: 251.496s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'norm_letters')
# train time: 303.373s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'pruning10')
# train time: 143.056s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'pruning5')
# train time: 170.188s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls')
# train time: 257.246s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'norm_letters')
# train time: 319.395s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'pruning10')
# train time: 143.871s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'pruning5')
# train time: 176.900s
# SVM_radial_TF-IDF('stop_words', 'urls', 'norm_letters')
# train time: 339.983s
# SVM_radial_TF-IDF('stop_words', 'urls', 'pruning10')
# train time: 143.582s
# SVM_radial_TF-IDF('stop_words', 'urls', 'pruning5')
# train time: 179.136s
# SVM_radial_TF-IDF('stop_words', 'norm_letters', 'pruning10')
# train time: 149.525s
# SVM_radial_TF-IDF('stop_words', 'norm_letters', 'pruning5')
# train time: 191.360s
# SVM_radial_TF-IDF('stemming', 'urls', 'norm_letters')
# train time: 304.543s
# SVM_radial_TF-IDF('stemming', 'urls', 'pruning10')
# train time: 168.801s
# SVM_radial_TF-IDF('stemming', 'urls', 'pruning5')
# train time: 207.593s
# SVM_radial_TF-IDF('stemming', 'norm_letters', 'pruning10')
# train time: 180.883s
# SVM_radial_TF-IDF('stemming', 'norm_letters', 'pruning5')
# train time: 228.572s
# SVM_radial_TF-IDF('lemmatization', 'urls', 'norm_letters')
# train time: 321.359s
# SVM_radial_TF-IDF('lemmatization', 'urls', 'pruning10')
# train time: 164.426s
# SVM_radial_TF-IDF('lemmatization', 'urls', 'pruning5')
# train time: 206.690s
# SVM_radial_TF-IDF('lemmatization', 'norm_letters', 'pruning10')
# train time: 180.150s
# SVM_radial_TF-IDF('lemmatization', 'norm_letters', 'pruning5')
# train time: 221.822s
# SVM_radial_TF-IDF('urls', 'norm_letters', 'pruning10')
# train time: 195.198s
# SVM_radial_TF-IDF('urls', 'norm_letters', 'pruning5')
# train time: 240.677s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls', 'norm_letters')
# train time: 258.252s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls', 'pruning10')
# train time: 140.852s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls', 'pruning5')
# train time: 176.106s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'norm_letters', 'pruning10')
# train time: 143.598s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'norm_letters', 'pruning5')
# train time: 174.414s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls', 'norm_letters')
# train time: 258.741s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls', 'pruning10')
# train time: 140.363s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls', 'pruning5')
# train time: 175.401s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'norm_letters', 'pruning10')
# train time: 143.981s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'norm_letters', 'pruning5')
# train time: 177.988s
# SVM_radial_TF-IDF('stop_words', 'urls', 'norm_letters', 'pruning10')
# train time: 151.354s
# SVM_radial_TF-IDF('stop_words', 'urls', 'norm_letters', 'pruning5')
# train time: 182.632s
# SVM_radial_TF-IDF('stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 175.937s
# SVM_radial_TF-IDF('stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 212.968s
# SVM_radial_TF-IDF('lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 173.102s
# SVM_radial_TF-IDF('lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 218.322s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 141.892s
# SVM_radial_TF-IDF('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 178.688s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 146.234s
# SVM_radial_TF-IDF('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 177.683s
# SVM_radial_Binario('stop_words',)
# train time: 268.865s
# SVM_radial_Binario('stemming',)
# train time: 285.443s
# SVM_radial_Binario('lemmatization',)
# train time: 279.992s
# SVM_radial_Binario('urls',)
# train time: 333.652s
# SVM_radial_Binario('norm_letters',)
# train time: 384.423s
# SVM_radial_Binario('pruning10',)
# train time: 201.428s
# SVM_radial_Binario('pruning5',)
# train time: 237.240s
# SVM_radial_Binario('stop_words', 'stemming')
# train time: 237.071s
# SVM_radial_Binario('stop_words', 'lemmatization')
# train time: 228.311s
# SVM_radial_Binario('stop_words', 'urls')
# train time: 241.685s
# SVM_radial_Binario('stop_words', 'norm_letters')
# train time: 269.613s
# SVM_radial_Binario('stop_words', 'pruning10')
# train time: 126.627s
# SVM_radial_Binario('stop_words', 'pruning5')
# train time: 170.544s
# SVM_radial_Binario('stemming', 'urls')
# train time: 253.497s
# SVM_radial_Binario('stemming', 'norm_letters')
# train time: 287.286s
# SVM_radial_Binario('stemming', 'pruning10')
# train time: 182.452s
# SVM_radial_Binario('stemming', 'pruning5')
# train time: 225.637s
# SVM_radial_Binario('lemmatization', 'urls')
# train time: 265.222s
# SVM_radial_Binario('lemmatization', 'norm_letters')
# train time: 290.237s
# SVM_radial_Binario('lemmatization', 'pruning10')
# train time: 175.992s
# SVM_radial_Binario('lemmatization', 'pruning5')
# train time: 224.057s
# SVM_radial_Binario('urls', 'norm_letters')
# train time: 327.475s
# SVM_radial_Binario('urls', 'pruning10')
# train time: 189.914s
# SVM_radial_Binario('urls', 'pruning5')
# train time: 245.437s
# SVM_radial_Binario('norm_letters', 'pruning10')
# train time: 198.537s
# SVM_radial_Binario('norm_letters', 'pruning5')
# train time: 257.694s
# SVM_radial_Binario('stop_words', 'stemming', 'urls')
# train time: 205.095s
# SVM_radial_Binario('stop_words', 'stemming', 'norm_letters')
# train time: 233.796s
# SVM_radial_Binario('stop_words', 'stemming', 'pruning10')
# train time: 130.245s
# SVM_radial_Binario('stop_words', 'stemming', 'pruning5')
# train time: 171.718s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls')
# train time: 207.070s
# SVM_radial_Binario('stop_words', 'lemmatization', 'norm_letters')
# train time: 221.116s
# SVM_radial_Binario('stop_words', 'lemmatization', 'pruning10')
# train time: 128.539s
# SVM_radial_Binario('stop_words', 'lemmatization', 'pruning5')
# train time: 169.533s
# SVM_radial_Binario('stop_words', 'urls', 'norm_letters')
# train time: 252.643s
# SVM_radial_Binario('stop_words', 'urls', 'pruning10')
# train time: 126.726s
# SVM_radial_Binario('stop_words', 'urls', 'pruning5')
# train time: 164.679s
# SVM_radial_Binario('stop_words', 'norm_letters', 'pruning10')
# train time: 132.823s
# SVM_radial_Binario('stop_words', 'norm_letters', 'pruning5')
# train time: 166.591s
# SVM_radial_Binario('stemming', 'urls', 'norm_letters')
# train time: 273.229s
# SVM_radial_Binario('stemming', 'urls', 'pruning10')
# train time: 179.278s
# SVM_radial_Binario('stemming', 'urls', 'pruning5')
# train time: 212.420s
# SVM_radial_Binario('stemming', 'norm_letters', 'pruning10')
# train time: 202.580s
# SVM_radial_Binario('stemming', 'norm_letters', 'pruning5')
# train time: 234.479s
# SVM_radial_Binario('lemmatization', 'urls', 'norm_letters')
# train time: 270.069s
# SVM_radial_Binario('lemmatization', 'urls', 'pruning10')
# train time: 169.125s
# SVM_radial_Binario('lemmatization', 'urls', 'pruning5')
# train time: 218.578s
# SVM_radial_Binario('lemmatization', 'norm_letters', 'pruning10')
# train time: 181.707s
# SVM_radial_Binario('lemmatization', 'norm_letters', 'pruning5')
# train time: 211.413s
# SVM_radial_Binario('urls', 'norm_letters', 'pruning10')
# train time: 198.687s
# SVM_radial_Binario('urls', 'norm_letters', 'pruning5')
# train time: 253.274s
# SVM_radial_Binario('stop_words', 'stemming', 'urls', 'norm_letters')
# train time: 202.418s
# SVM_radial_Binario('stop_words', 'stemming', 'urls', 'pruning10')
# train time: 128.547s
# SVM_radial_Binario('stop_words', 'stemming', 'urls', 'pruning5')
# train time: 157.489s
# SVM_radial_Binario('stop_words', 'stemming', 'norm_letters', 'pruning10')
# train time: 140.632s
# SVM_radial_Binario('stop_words', 'stemming', 'norm_letters', 'pruning5')
# train time: 166.626s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls', 'norm_letters')
# train time: 208.540s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls', 'pruning10')
# train time: 124.956s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls', 'pruning5')
# train time: 164.806s
# SVM_radial_Binario('stop_words', 'lemmatization', 'norm_letters', 'pruning10')
# train time: 133.332s
# SVM_radial_Binario('stop_words', 'lemmatization', 'norm_letters', 'pruning5')
# train time: 166.003s
# SVM_radial_Binario('stop_words', 'urls', 'norm_letters', 'pruning10')
# train time: 126.935s
# SVM_radial_Binario('stop_words', 'urls', 'norm_letters', 'pruning5')
# train time: 167.223s
# SVM_radial_Binario('stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 180.684s
# SVM_radial_Binario('stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 220.922s
# SVM_radial_Binario('lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 179.421s
# SVM_radial_Binario('lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 218.345s
# SVM_radial_Binario('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning10')
# train time: 135.733s
# SVM_radial_Binario('stop_words', 'stemming', 'urls', 'norm_letters', 'pruning5')
# train time: 165.274s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning10')
# train time: 132.819s
# SVM_radial_Binario('stop_words', 'lemmatization', 'urls', 'norm_letters', 'pruning5')
# train time: 165.595s

# %%
max(results_list)
# Out:
# (0.9072128851540616,
#  32068,
#  0.9046244339777281,
#  0.9043875156512795,
#  0.9048673367705735,
#  6123,
#  4241,
#  520,
#  540,
#  'SVM_radial_TF-IDF',
#  "('stemming', 'norm_letters')")

# %%
len(results_list)
# Out:
# 213

# %%
results_list_backup = results_list

# %%
results_df = pd.DataFrame(results_list)

# %%
results_df.head()
# Out:
#          0      1         2         3         4     5     6    7    8   \
# 0  0.892069  48118  0.888335  0.891067  0.886149  6140  4051  712  521
# 1  0.906688  32850  0.903828  0.904772  0.902962  6164  4194  569  497
# 2  0.904762  36771  0.901873  0.902673  0.901131  6148  4188  575  513
# 3  0.903274  40441  0.900356  0.901084  0.899676  6137  4182  581  524
# 4  0.902836  47582  0.899864  0.900771  0.899031  6141  4173  590  520
#
#               9                   10
# 0  SVM_radial_TF     ('stop_words',)
# 1  SVM_radial_TF       ('stemming',)
# 2  SVM_radial_TF  ('lemmatization',)
# 3  SVM_radial_TF           ('urls',)
# 4  SVM_radial_TF   ('norm_letters',)

# %%
results_df = results_df[[9, 10, 1, 0, 2, 3, 4, 5, 6, 7, 8]]

# %%
results_df
# Out:
#                      9                                                  10  \
# 0         SVM_radial_TF                                    ('stop_words',)
# 1         SVM_radial_TF                                      ('stemming',)
# 2         SVM_radial_TF                                 ('lemmatization',)
# 3         SVM_radial_TF                                          ('urls',)
# 4         SVM_radial_TF                                  ('norm_letters',)
# 5         SVM_radial_TF                                     ('pruning10',)
# 6         SVM_radial_TF                                      ('pruning5',)
# 7         SVM_radial_TF                         ('stop_words', 'stemming')
# 8         SVM_radial_TF                    ('stop_words', 'lemmatization')
# 9         SVM_radial_TF                             ('stop_words', 'urls')
# 10        SVM_radial_TF                     ('stop_words', 'norm_letters')
# 11        SVM_radial_TF                        ('stop_words', 'pruning10')
# 12        SVM_radial_TF                         ('stop_words', 'pruning5')
# 13        SVM_radial_TF                               ('stemming', 'urls')
# 14        SVM_radial_TF                       ('stemming', 'norm_letters')
# 15        SVM_radial_TF                          ('stemming', 'pruning10')
# 16        SVM_radial_TF                           ('stemming', 'pruning5')
# 17        SVM_radial_TF                          ('lemmatization', 'urls')
# 18        SVM_radial_TF                  ('lemmatization', 'norm_letters')
# 19        SVM_radial_TF                     ('lemmatization', 'pruning10')
# 20        SVM_radial_TF                      ('lemmatization', 'pruning5')
# 21        SVM_radial_TF                           ('urls', 'norm_letters')
# 22        SVM_radial_TF                              ('urls', 'pruning10')
# 23        SVM_radial_TF                               ('urls', 'pruning5')
# 24        SVM_radial_TF                      ('norm_letters', 'pruning10')
# 25        SVM_radial_TF                       ('norm_letters', 'pruning5')
# 26        SVM_radial_TF                 ('stop_words', 'stemming', 'urls')
# 27        SVM_radial_TF         ('stop_words', 'stemming', 'norm_letters')
# 28        SVM_radial_TF            ('stop_words', 'stemming', 'pruning10')
# 29        SVM_radial_TF             ('stop_words', 'stemming', 'pruning5')
# ..                  ...                                                ...
# 183  SVM_radial_Binario                   ('stemming', 'urls', 'pruning5')
# 184  SVM_radial_Binario          ('stemming', 'norm_letters', 'pruning10')
# 185  SVM_radial_Binario           ('stemming', 'norm_letters', 'pruning5')
# 186  SVM_radial_Binario          ('lemmatization', 'urls', 'norm_letters')
# 187  SVM_radial_Binario             ('lemmatization', 'urls', 'pruning10')
# 188  SVM_radial_Binario              ('lemmatization', 'urls', 'pruning5')
# 189  SVM_radial_Binario     ('lemmatization', 'norm_letters', 'pruning10')
# 190  SVM_radial_Binario      ('lemmatization', 'norm_letters', 'pruning5')
# 191  SVM_radial_Binario              ('urls', 'norm_letters', 'pruning10')
# 192  SVM_radial_Binario               ('urls', 'norm_letters', 'pruning5')
# 193  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 194  SVM_radial_Binario    ('stop_words', 'stemming', 'urls', 'pruning10')
# 195  SVM_radial_Binario     ('stop_words', 'stemming', 'urls', 'pruning5')
# 196  SVM_radial_Binario  ('stop_words', 'stemming', 'norm_letters', 'pr...
# 197  SVM_radial_Binario  ('stop_words', 'stemming', 'norm_letters', 'pr...
# 198  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
# 199  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'pruni...
# 200  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'pruni...
# 201  SVM_radial_Binario  ('stop_words', 'lemmatization', 'norm_letters'...
# 202  SVM_radial_Binario  ('stop_words', 'lemmatization', 'norm_letters'...
# 203  SVM_radial_Binario  ('stop_words', 'urls', 'norm_letters', 'prunin...
# 204  SVM_radial_Binario  ('stop_words', 'urls', 'norm_letters', 'prunin...
# 205  SVM_radial_Binario  ('stemming', 'urls', 'norm_letters', 'pruning10')
# 206  SVM_radial_Binario   ('stemming', 'urls', 'norm_letters', 'pruning5')
# 207  SVM_radial_Binario  ('lemmatization', 'urls', 'norm_letters', 'pru...
# 208  SVM_radial_Binario  ('lemmatization', 'urls', 'norm_letters', 'pru...
# 209  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 210  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 211  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
# 212  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
#
#         1         0         2         3         4     5     6    7    8
# 0    48118  0.892069  0.888335  0.891067  0.886149  6140  4051  712  521
# 1    32850  0.906688  0.903828  0.904772  0.902962  6164  4194  569  497
# 2    36771  0.904762  0.901873  0.902673  0.901131  6148  4188  575  513
# 3    40441  0.903274  0.900356  0.901084  0.899676  6137  4182  581  524
# 4    47582  0.902836  0.899864  0.900771  0.899031  6141  4173  590  520
# 5     4348  0.895221  0.892039  0.892834  0.891304  6094  4133  630  567
# 6     7854  0.897496  0.894332  0.895351  0.893405  6115  4138  625  546
# 7    32764  0.897759  0.894385  0.896377  0.892703  6149  4107  656  512
# 8    36707  0.898810  0.895443  0.897568  0.893664  6159  4109  654  502
# 9    40187  0.891632  0.887872  0.890651  0.885654  6139  4047  716  522
# 10   47328  0.892507  0.888770  0.891590  0.886524  6145  4051  712  516
# 11    4169  0.882003  0.877973  0.880422  0.875991  6076  4000  763  585
# 12    7650  0.888218  0.884419  0.886826  0.882457  6109  4038  725  552
# 13   24920  0.906775  0.903885  0.904986  0.902888  6170  4189  574  491
# 14   32041  0.905987  0.903094  0.904093  0.902182  6162  4188  575  499
# 15    3574  0.904324  0.901333  0.902544  0.900247  6160  4171  592  501
# 16    5742  0.904412  0.901339  0.902955  0.899934  6174  4158  605  487
# 17   28839  0.905200  0.902327  0.903115  0.901596  6150  4191  572  511
# 18   36069  0.906075  0.903217  0.904062  0.902437  6157  4194  569  504
# 19    3598  0.902924  0.899864  0.901187  0.898687  6156  4159  604  505
# 20    6031  0.905200  0.902211  0.903543  0.901028  6169  4172  591  492
# 21   39652  0.903186  0.900262  0.901005  0.899571  6137  4181  582  524
# 22    4340  0.894258  0.891037  0.891870  0.890269  6090  4126  637  571
# 23    7842  0.896534  0.893349  0.894325  0.892460  6108  4134  629  553
# 24    4353  0.895483  0.892327  0.893054  0.891649  6093  4137  626  568
# 25    7847  0.897672  0.894532  0.895469  0.893675  6113  4142  621  548
# 26   24834  0.898459  0.895094  0.897154  0.893364  6155  4109  654  506
# 27   31957  0.898459  0.895169  0.896883  0.893693  6144  4120  643  517
# 28    3495  0.894433  0.890863  0.893225  0.888923  6142  4076  687  519
# 29    5662  0.895046  0.891543  0.893697  0.889748  6139  4086  677  522
# ..     ...       ...       ...       ...       ...   ...   ...  ...  ...
# 183   5727  0.903011  0.900007  0.901084  0.899032  6148  4168  595  513
# 184   3583  0.903536  0.900486  0.901857  0.899273  6161  4161  602  500
# 185   5742  0.902486  0.899491  0.900453  0.898611  6141  4169  594  520
# 186  28138  0.904937  0.902138  0.902563  0.901730  6135  4203  560  526
# 187   3590  0.903887  0.900854  0.902195  0.899663  6162  4164  599  499
# 188   6017  0.902836  0.899877  0.900728  0.899091  6139  4175  588  522
# 189   3601  0.903274  0.900269  0.901389  0.899257  6151  4168  595  510
# 190   6014  0.904237  0.901289  0.902284  0.900382  6152  4178  585  509
# 191   4347  0.891894  0.888653  0.889282  0.888063  6069  4120  643  592
# 192   7833  0.895921  0.892728  0.893660  0.891875  6103  4132  631  558
# 193  24029  0.897759  0.894439  0.896181  0.892942  6141  4115  648  520
# 194   3486  0.893557  0.889980  0.892239  0.888113  6134  4074  689  527
# 195   5647  0.895483  0.892034  0.894014  0.890363  6136  4094  669  525
# 196   3505  0.893645  0.890053  0.892393  0.888128  6137  4072  691  524
# 197   5662  0.897584  0.894204  0.896195  0.892523  6148  4106  657  513
# 198  28073  0.898109  0.894726  0.896816  0.892974  6154  4106  657  507
# 199   3528  0.893995  0.890400  0.892809  0.888429  6141  4072  691  520
# 200   5954  0.897321  0.893846  0.896242  0.891879  6159  4092  671  502
# 201   3538  0.895571  0.892072  0.894293  0.890228  6144  4087  676  517
# 202   5950  0.897321  0.893874  0.896138  0.891999  6155  4096  667  506
# 203   4168  0.882003  0.877900  0.880646  0.875722  6085  3991  772  576
# 204   7629  0.886992  0.883168  0.885501  0.881257  6100  4033  730  561
# 205   3575  0.903186  0.900125  0.901494  0.898913  6159  4159  604  502
# 206   5725  0.903274  0.900275  0.901367  0.899287  6150  4169  594  511
# 207   3594  0.903011  0.900014  0.901062  0.899062  6147  4169  594  514
# 208   5998  0.903449  0.900518  0.901329  0.899766  6141  4180  583  520
# 209   3497  0.894870  0.891348  0.893565  0.889508  6140  4083  680  521
# 210   5645  0.897496  0.894165  0.895921  0.892657  6140  4113  650  521
# 211   3531  0.895133  0.891580  0.893979  0.889614  6147  4079  684  514
# 212   5934  0.896709  0.893258  0.895437  0.891443  6149  4095  668  512
#
# [213 rows x 11 columns]

# %%
results_df.columns = ['clf_name','comb','features_number','accuracy','f1_score','precision','recall','true_positives','true_negatives','false_positives','false_negatives']

# %%
results_df
# Out:
#                clf_name                                               comb  \
# 0         SVM_radial_TF                                    ('stop_words',)
# 1         SVM_radial_TF                                      ('stemming',)
# 2         SVM_radial_TF                                 ('lemmatization',)
# 3         SVM_radial_TF                                          ('urls',)
# 4         SVM_radial_TF                                  ('norm_letters',)
# 5         SVM_radial_TF                                     ('pruning10',)
# 6         SVM_radial_TF                                      ('pruning5',)
# 7         SVM_radial_TF                         ('stop_words', 'stemming')
# 8         SVM_radial_TF                    ('stop_words', 'lemmatization')
# 9         SVM_radial_TF                             ('stop_words', 'urls')
# 10        SVM_radial_TF                     ('stop_words', 'norm_letters')
# 11        SVM_radial_TF                        ('stop_words', 'pruning10')
# 12        SVM_radial_TF                         ('stop_words', 'pruning5')
# 13        SVM_radial_TF                               ('stemming', 'urls')
# 14        SVM_radial_TF                       ('stemming', 'norm_letters')
# 15        SVM_radial_TF                          ('stemming', 'pruning10')
# 16        SVM_radial_TF                           ('stemming', 'pruning5')
# 17        SVM_radial_TF                          ('lemmatization', 'urls')
# 18        SVM_radial_TF                  ('lemmatization', 'norm_letters')
# 19        SVM_radial_TF                     ('lemmatization', 'pruning10')
# 20        SVM_radial_TF                      ('lemmatization', 'pruning5')
# 21        SVM_radial_TF                           ('urls', 'norm_letters')
# 22        SVM_radial_TF                              ('urls', 'pruning10')
# 23        SVM_radial_TF                               ('urls', 'pruning5')
# 24        SVM_radial_TF                      ('norm_letters', 'pruning10')
# 25        SVM_radial_TF                       ('norm_letters', 'pruning5')
# 26        SVM_radial_TF                 ('stop_words', 'stemming', 'urls')
# 27        SVM_radial_TF         ('stop_words', 'stemming', 'norm_letters')
# 28        SVM_radial_TF            ('stop_words', 'stemming', 'pruning10')
# 29        SVM_radial_TF             ('stop_words', 'stemming', 'pruning5')
# ..                  ...                                                ...
# 183  SVM_radial_Binario                   ('stemming', 'urls', 'pruning5')
# 184  SVM_radial_Binario          ('stemming', 'norm_letters', 'pruning10')
# 185  SVM_radial_Binario           ('stemming', 'norm_letters', 'pruning5')
# 186  SVM_radial_Binario          ('lemmatization', 'urls', 'norm_letters')
# 187  SVM_radial_Binario             ('lemmatization', 'urls', 'pruning10')
# 188  SVM_radial_Binario              ('lemmatization', 'urls', 'pruning5')
# 189  SVM_radial_Binario     ('lemmatization', 'norm_letters', 'pruning10')
# 190  SVM_radial_Binario      ('lemmatization', 'norm_letters', 'pruning5')
# 191  SVM_radial_Binario              ('urls', 'norm_letters', 'pruning10')
# 192  SVM_radial_Binario               ('urls', 'norm_letters', 'pruning5')
# 193  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 194  SVM_radial_Binario    ('stop_words', 'stemming', 'urls', 'pruning10')
# 195  SVM_radial_Binario     ('stop_words', 'stemming', 'urls', 'pruning5')
# 196  SVM_radial_Binario  ('stop_words', 'stemming', 'norm_letters', 'pr...
# 197  SVM_radial_Binario  ('stop_words', 'stemming', 'norm_letters', 'pr...
# 198  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
# 199  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'pruni...
# 200  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'pruni...
# 201  SVM_radial_Binario  ('stop_words', 'lemmatization', 'norm_letters'...
# 202  SVM_radial_Binario  ('stop_words', 'lemmatization', 'norm_letters'...
# 203  SVM_radial_Binario  ('stop_words', 'urls', 'norm_letters', 'prunin...
# 204  SVM_radial_Binario  ('stop_words', 'urls', 'norm_letters', 'prunin...
# 205  SVM_radial_Binario  ('stemming', 'urls', 'norm_letters', 'pruning10')
# 206  SVM_radial_Binario   ('stemming', 'urls', 'norm_letters', 'pruning5')
# 207  SVM_radial_Binario  ('lemmatization', 'urls', 'norm_letters', 'pru...
# 208  SVM_radial_Binario  ('lemmatization', 'urls', 'norm_letters', 'pru...
# 209  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 210  SVM_radial_Binario  ('stop_words', 'stemming', 'urls', 'norm_lette...
# 211  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
# 212  SVM_radial_Binario  ('stop_words', 'lemmatization', 'urls', 'norm_...
#
#      features_number  accuracy  f1_score  precision    recall  true_positives  \
# 0              48118  0.892069  0.888335   0.891067  0.886149            6140
# 1              32850  0.906688  0.903828   0.904772  0.902962            6164
# 2              36771  0.904762  0.901873   0.902673  0.901131            6148
# 3              40441  0.903274  0.900356   0.901084  0.899676            6137
# 4              47582  0.902836  0.899864   0.900771  0.899031            6141
# 5               4348  0.895221  0.892039   0.892834  0.891304            6094
# 6               7854  0.897496  0.894332   0.895351  0.893405            6115
# 7              32764  0.897759  0.894385   0.896377  0.892703            6149
# 8              36707  0.898810  0.895443   0.897568  0.893664            6159
# 9              40187  0.891632  0.887872   0.890651  0.885654            6139
# 10             47328  0.892507  0.888770   0.891590  0.886524            6145
# 11              4169  0.882003  0.877973   0.880422  0.875991            6076
# 12              7650  0.888218  0.884419   0.886826  0.882457            6109
# 13             24920  0.906775  0.903885   0.904986  0.902888            6170
# 14             32041  0.905987  0.903094   0.904093  0.902182            6162
# 15              3574  0.904324  0.901333   0.902544  0.900247            6160
# 16              5742  0.904412  0.901339   0.902955  0.899934            6174
# 17             28839  0.905200  0.902327   0.903115  0.901596            6150
# 18             36069  0.906075  0.903217   0.904062  0.902437            6157
# 19              3598  0.902924  0.899864   0.901187  0.898687            6156
# 20              6031  0.905200  0.902211   0.903543  0.901028            6169
# 21             39652  0.903186  0.900262   0.901005  0.899571            6137
# 22              4340  0.894258  0.891037   0.891870  0.890269            6090
# 23              7842  0.896534  0.893349   0.894325  0.892460            6108
# 24              4353  0.895483  0.892327   0.893054  0.891649            6093
# 25              7847  0.897672  0.894532   0.895469  0.893675            6113
# 26             24834  0.898459  0.895094   0.897154  0.893364            6155
# 27             31957  0.898459  0.895169   0.896883  0.893693            6144
# 28              3495  0.894433  0.890863   0.893225  0.888923            6142
# 29              5662  0.895046  0.891543   0.893697  0.889748            6139
# ..               ...       ...       ...        ...       ...             ...
# 183             5727  0.903011  0.900007   0.901084  0.899032            6148
# 184             3583  0.903536  0.900486   0.901857  0.899273            6161
# 185             5742  0.902486  0.899491   0.900453  0.898611            6141
# 186            28138  0.904937  0.902138   0.902563  0.901730            6135
# 187             3590  0.903887  0.900854   0.902195  0.899663            6162
# 188             6017  0.902836  0.899877   0.900728  0.899091            6139
# 189             3601  0.903274  0.900269   0.901389  0.899257            6151
# 190             6014  0.904237  0.901289   0.902284  0.900382            6152
# 191             4347  0.891894  0.888653   0.889282  0.888063            6069
# 192             7833  0.895921  0.892728   0.893660  0.891875            6103
# 193            24029  0.897759  0.894439   0.896181  0.892942            6141
# 194             3486  0.893557  0.889980   0.892239  0.888113            6134
# 195             5647  0.895483  0.892034   0.894014  0.890363            6136
# 196             3505  0.893645  0.890053   0.892393  0.888128            6137
# 197             5662  0.897584  0.894204   0.896195  0.892523            6148
# 198            28073  0.898109  0.894726   0.896816  0.892974            6154
# 199             3528  0.893995  0.890400   0.892809  0.888429            6141
# 200             5954  0.897321  0.893846   0.896242  0.891879            6159
# 201             3538  0.895571  0.892072   0.894293  0.890228            6144
# 202             5950  0.897321  0.893874   0.896138  0.891999            6155
# 203             4168  0.882003  0.877900   0.880646  0.875722            6085
# 204             7629  0.886992  0.883168   0.885501  0.881257            6100
# 205             3575  0.903186  0.900125   0.901494  0.898913            6159
# 206             5725  0.903274  0.900275   0.901367  0.899287            6150
# 207             3594  0.903011  0.900014   0.901062  0.899062            6147
# 208             5998  0.903449  0.900518   0.901329  0.899766            6141
# 209             3497  0.894870  0.891348   0.893565  0.889508            6140
# 210             5645  0.897496  0.894165   0.895921  0.892657            6140
# 211             3531  0.895133  0.891580   0.893979  0.889614            6147
# 212             5934  0.896709  0.893258   0.895437  0.891443            6149
#
#      true_negatives  false_positives  false_negatives
# 0              4051              712              521
# 1              4194              569              497
# 2              4188              575              513
# 3              4182              581              524
# 4              4173              590              520
# 5              4133              630              567
# 6              4138              625              546
# 7              4107              656              512
# 8              4109              654              502
# 9              4047              716              522
# 10             4051              712              516
# 11             4000              763              585
# 12             4038              725              552
# 13             4189              574              491
# 14             4188              575              499
# 15             4171              592              501
# 16             4158              605              487
# 17             4191              572              511
# 18             4194              569              504
# 19             4159              604              505
# 20             4172              591              492
# 21             4181              582              524
# 22             4126              637              571
# 23             4134              629              553
# 24             4137              626              568
# 25             4142              621              548
# 26             4109              654              506
# 27             4120              643              517
# 28             4076              687              519
# 29             4086              677              522
# ..              ...              ...              ...
# 183            4168              595              513
# 184            4161              602              500
# 185            4169              594              520
# 186            4203              560              526
# 187            4164              599              499
# 188            4175              588              522
# 189            4168              595              510
# 190            4178              585              509
# 191            4120              643              592
# 192            4132              631              558
# 193            4115              648              520
# 194            4074              689              527
# 195            4094              669              525
# 196            4072              691              524
# 197            4106              657              513
# 198            4106              657              507
# 199            4072              691              520
# 200            4092              671              502
# 201            4087              676              517
# 202            4096              667              506
# 203            3991              772              576
# 204            4033              730              561
# 205            4159              604              502
# 206            4169              594              511
# 207            4169              594              514
# 208            4180              583              520
# 209            4083              680              521
# 210            4113              650              521
# 211            4079              684              514
# 212            4095              668              512
#
# [213 rows x 11 columns]

# %%
len(results_df)
# Out:
# 213

# %%
results_df.to_csv('result_twitter_sa_combinations_svm_rbf.csv', sep='\t')

# %%
results_tweets_df = results_df[results_df['clf_name'].str.contains('SVM_radial')]

# %%
len(results_tweets_df)
# Out:
# 213

# %%
filter_result = results_tweets_df.nsmallest(5, columns='accuracy')[['clf_name','comb','features_number','accuracy','f1_score']]

# %%
filter_result
# Out:
#                clf_name                                                 comb  \
# 106   SVM_radial_TF-IDF                  ('stop_words', 'urls', 'pruning10')
# 108   SVM_radial_TF-IDF          ('stop_words', 'norm_letters', 'pruning10')
# 132   SVM_radial_TF-IDF  ('stop_words', 'urls', 'norm_letters', 'pruning10')
# 82    SVM_radial_TF-IDF                          ('stop_words', 'pruning10')
# 153  SVM_radial_Binario                          ('stop_words', 'pruning10')
#
#      features_number  accuracy  f1_score
# 106             4165  0.877013  0.873224
# 108             4181  0.878764  0.875206
# 132             4175  0.878852  0.875170
# 82              4171  0.879814  0.876317
# 153             4169  0.881127  0.876978

# %%
filter_result.columns = ['Clf_Pon', 'Combinación', '# Car', 'Exact', 'V-F1']

# %%
pd.options.display.max_colwidth = 1000

# %%
print(filter_result.round(4).to_latex(index=False, column_format='|l|m{16em}|r|r|r|', decimal=','))
# Out:
# \begin{tabular}{|l|m{16em}|r|r|r|}
# \toprule
#             Clf\_Pon &                                          Combinación &  \# Car &   Exact &    V-F1 \\
# \midrule
#   SVM\_radial\_TF-IDF &                  ('stop\_words', 'urls', 'pruning10') &   4165 &  0,8770 &  0,8732 \\
#   SVM\_radial\_TF-IDF &          ('stop\_words', 'norm\_letters', 'pruning10') &   4181 &  0,8788 &  0,8752 \\
#   SVM\_radial\_TF-IDF &  ('stop\_words', 'urls', 'norm\_letters', 'pruning10') &   4175 &  0,8789 &  0,8752 \\
#   SVM\_radial\_TF-IDF &                          ('stop\_words', 'pruning10') &   4171 &  0,8798 &  0,8763 \\
#  SVM\_radial\_Binario &                          ('stop\_words', 'pruning10') &   4169 &  0,8811 &  0,8770 \\
# \bottomrule
# \end{tabular}
